# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 7.2 MB/s eta 0:05:42
#      ---------------------------------------- 0.0/2.5 GB 11.3 MB/s eta 0:03:38
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:33
#      ---------------------------------------- 0.0/2.5 GB 11.5 MB/s eta 0:03:33
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:33
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:32
#      ---------------------------------------- 0.0/2.5 GB 11.7 MB/s eta 0:03:31
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:31
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:32
#      ---------------------------------------- 0.0/2.5 GB 11.6 MB/s eta 0:03:31
# ...

# %%
pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.19-py3-none-any.whl.metadata (40 kB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.3 MB/s eta 0:00:00
# ...
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -------------------------------------- 162.3/162.3 kB 4.8 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
print("hello")
# Out:
# hello

# %%
from ultralytics import YOLO
model=YOLO(r"D:\rahul\disease\New folder\yolov8n.pt")

# %%
model.train(data=r"D:\rahul\disease\New folder\tomato.yaml",epochs=25)
# Out:
# New https://pypi.org/project/ultralytics/8.1.26 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.19 🚀 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...

# %%
model = YOLO(r"D:\rahul\disease\New folder\runs\detect\train112\weights\best.pt")

# %%
results = model.predict(r"D:\rahul\disease\New folder\val\images\0c91af09-0ad7-46a1-844b-edfd6af34df2___Com.G_TgS_FL 9776.JPG")
# Out:
# image 1/1 D:\rahul\disease\New folder\val\images\0c91af09-0ad7-46a1-844b-edfd6af34df2___Com.G_TgS_FL 9776.JPG: 640x640 1 Tomato___Target_Spot, 0.0ms
# Speed: 99.9ms preprocess, 0.0ms inference, 260.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
import numpy as np

def find_bounding_boxes(image_path, min_contour_area=500):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply GaussianBlur to reduce noise and help contour detection
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    
    # Use Canny edge detection to find edges in the image
    edges = cv2.Canny(blurred, 50, 150)
    
    # Find contours in the edged image
    contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Loop over the contours
    for contour in contours:
        # Ignore small contours
        if cv2.contourArea(contour) > min_contour_area:
            # Get the bounding box coordinates
            x, y, w, h = cv2.boundingRect(contour)
            
            # Draw the bounding box on the original image
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    # Display the image with bounding boxes
    cv2.imshow('Bounding Boxes', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Replace 'path/to/your/image.jpg' with the actual path to your image
image_path = r'D:\rahul\disease\New folder\train\images\(2148).JPG'
find_bounding_boxes(image_path)

# %%
import cv2

def find_bounding_boxes(image_path, min_contour_area=500):
    # Read the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply GaussianBlur to reduce noise and help contour detection
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    
    # Use Canny edge detection to find edges in the image
    edges = cv2.Canny(blurred, 50, 150)
    
    # Find contours in the edged image
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Loop over the contours
    for contour in contours:
        # Ignore small contours
        if cv2.contourArea(contour) > min_contour_area:
            # Get the bounding box coordinates
            x, y, w, h = cv2.boundingRect(contour)
            
            # Draw the bounding box on the original image
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
    # Display the image with bounding boxes
    cv2.imshow('Bounding Boxes', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Replace 'path/to/your/image.jpg' with the actual path to your image
image_path = r"D:\rahul\disease\New folder\train\images\(2148).JPG"
find_bounding_boxes(image_path)

# %%
import cv2

# %%
pip install pylabel
# Out:
# ...
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ---------------------------------------- 0.0/367.8 kB ? eta -:--:--
#    ---------------------- ----------------- 204.8/367.8 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 367.8/367.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 9.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/10.6 MB 10.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/10.6 MB 11.0 MB/s eta 0:00:01
#    ------- -------------------------------- 2.1/10.6 MB 11.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/10.6 MB 11.3 MB/s eta 0:00:01
#    ------------ --------------------------- 3.2/10.6 MB 11.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.8/10.6 MB 11.4 MB/s eta 0:00:01
# ...

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)

# %%
import os, zipfile

# %%
from pylabel import importer

# %%
path_to_annotations = r"D:\rahul\disease\New folder\train\labels"

#Identify the path to get from the annotations to the images 
path_to_images = r"D:\rahul\disease\New folder\train\images"

#Import the dataset into the pylable schema 
#Class names are defined here https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml
yoloclasses = ["Tomato___Tomato_mosaic_virus"
,"Tomato___Bacterial_spot"
,"Tomato___Early_blight"
,"Tomato___Late_blight"
,"Tomato___Leaf_Mold"
,"Tomato___Spider_mites Two-spotted_spider_mite"
,"Tomato___Target_Spot"
,"Tomato___Tomato_Yellow_Leaf_Curl_Virus"
,"Tomato___Septoria_leaf_spot"
,"Tomato___healthy"
]
dataset = importer.ImportYoloV5(path=path_to_annotations, path_to_images=path_to_images, cat_names=yoloclasses,
    img_ext="jpg", name="coco128")

dataset.df.head(5)
# Out:
# Importing YOLO files...:   6%|▋         | 6866/107777 [00:56<13:56, 120.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 19
#       6 #Import the dataset into the pylable schema
#       7 #Class names are defined here https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml
#       8 yoloclasses = ["Tomato___Tomato_mosaic_virus"
#       9 ,"Tomato___Bacterial_spot"
#      10 ,"Tomato___Early_blight"
#    (...)
#      17 ,"Tomato___healthy"
#      18 ]
# ---> 19 dataset = importer.ImportYoloV5(path=path_to_annotations, path_to_images=path_to_images, cat_names=yoloclasses,
#      20     img_ext="jpg", name="coco128")
#      22 dataset.df.head(5)
#
# File d:\users\envs\rahul\Lib\site-packages\pylabel\importer.py:320, in ImportYoloV5(path, img_ext, cat_names, path_to_images, name, encoding)
# ...

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes:{dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(f"Number of images: {dataset.analyze.num_images}")
#       2 print(f"Number of classes: {dataset.analyze.num_classes}")
#       3 print(f"Classes:{dataset.analyze.classes}")
#
# NameError: name 'dataset' is not defined

# %%
from IPython.display import Image, display
display(dataset.visualize.ShowBoundingBoxes(80))
display(dataset.visualize.ShowBoundingBoxes(46))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from IPython.display import Image, display
# ----> 2 display(dataset.visualize.ShowBoundingBoxes(80))
#       3 display(dataset.visualize.ShowBoundingBoxes(46))
#
# NameError: name 'dataset' is not defined

# %%
from os import listdir,remove
from os.path import isfile, join

images_path = r"D:\rahul\d\New folder\train\images"
annotations_path = r"D:\rahul\d\New folder\train\labels"


# this function will help to retrieve all files with provided extension in a given folder
def get_files_names_with_extension(full_path, ext):
    return [f for f in listdir(full_path) if isfile(join(full_path, f)) and f.lower().endswith(".{}".format(ext))]


images = get_files_names_with_extension(images_path, "jpg")
annotations = set([f.split(".")[0] for f in get_files_names_with_extension(annotations_path, "txt")])

for img in images:
    if img.split(".")[0] not in annotations:
        remove(join(images_path, img))

# %%
pip install pascal-voc
# Out:
# ...
#      ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#      ------------------------- ------------ 30.7/45.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 45.8/45.8 kB 756.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/427.6 kB ? eta -:--:--
#    ------------------------- -------------- 276.5/427.6 kB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 427.6/427.6 kB 6.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import os
output_path = str(Path(dataset.path_to_annotations, "../", "voc_annotations/"))

Path(output_path).mkdir(exist_ok=True)
dataset.export.ExportToVoc(output_path=output_path)[0]
# Out:
# Exporting VOC files...: 100%|██████████| 9799/9799 [00:21<00:00, 456.71it/s]
# 'D:\\rahul\\disease\\New folder\\train\\labels\\..\\voc_annotations\\65576adf-cef4-4f1a-8b7c-881e8729bdbf___GHLB2 Leaf 147.xml'

# %%
jpg_folder = r"D:\rahul\disease\New folder\train\images"
xml_folder = r"D:\rahul\disease\New folder\train\labels1"

# Get a list of all JPG files
jpg_files = [f for f in os.listdir(jpg_folder) if f.endswith(".jpg")]

# Get a list of all XML files
xml_files = [f for f in os.listdir(xml_folder) if f.endswith(".xml")]

# Find the missing XML file
missing_xml = list(set(jpg_files) - set(xml_files))

# If there is a missing XML file, delete the corresponding JPG file
print(missing_xml)
# if missing_xml:
#     missing_jpg = missing_xml[0].replace(".xml", ".jpg")
#     missing_jpg_path = os.path.join(jpg_folder, missing_jpg)

#     # Delete the specific JPG file
#     os.remove(missing_jpg_path)
#     print(f"{missing_jpg} has been deleted.")
# else:
#     print("All images have corresponding XML files.")
# Out:
# ['(5967).jpg', '(3296).jpg', '(4565).jpg', '(4578).jpg', '(4703).jpg', '(5318).jpg', '(6095).jpg', '(3464).jpg', '(7330).jpg', '(7866).jpg', '(2918).jpg', '(3684).jpg', '(4386).jpg', '(4521).jpg', '(8804).jpg', '(2972).jpg', '(4396).jpg', '(5639).jpg', '(3556).jpg', '(5411).jpg', '(5274).jpg', '(3182).jpg', '(8294).jpg', '(4250).jpg', '(3284).jpg', '(9710).jpg', '(4464).jpg', '(5797).jpg', '(4100).jpg', '(6070).jpg', '(8381).jpg', '(4806).jpg', '(8903).jpg', '(2618).jpg', '(5522).jpg', '(8986).jpg', '(5600).jpg', '(4482).jpg', '(5933).jpg', '(6501).jpg', '(5960).jpg', '(4485).jpg', '(5010).jpg', '(6235).jpg', '(8463).jpg', '(9396).jpg', '(6150).jpg', '(6744).jpg', '(9626).jpg', '(3660).jpg', '(4289).jpg', '(7722).jpg', '(8183).jpg', '(5245).jpg', '(3112).jpg', '(2909).jpg', '(6409).jpg', '(6736).jpg', '(8205).jpg', '(5926).jpg', '(7850).jpg', '(8407).jpg', '(9597).jpg', '(3942).jpg', '(5741).jpg', '(4728).jpg']

# %%
pwd
# Out:
# 'd:\\rahul\\disease\\New folder'

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("train/images/(854).JPG")
dh, dw, _ = img.shape
        
fl = open("train/labels/(854).txt", 'r')
data = fl.readlines()
fl.close()
        
for dt in data:
            
    _, x, y, w, h = dt.split(' ')
            
    nx = int(float(x)*dw)
    ny = int(float(y)*dh)
    nw = int(float(w)*dw)
    nh = int(float(h)*dh)
            
    cv2.rectangle(img, (nx,ny), (nx+nw,ny+nh), (0,0,255), 1)
            
plt.imshow(img)
